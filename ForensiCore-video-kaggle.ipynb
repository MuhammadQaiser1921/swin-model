# %% [markdown]
# # ForensiCore Video Training (Kaggle)
# This notebook runs the video pipeline from the shared launcher script.

# %%
# !pip -q install tensorflow-addons

# %%
from pathlib import Path
import importlib.util

launcher_path = Path('/kaggle/working/ForensiCore-train.py')
if not launcher_path.exists():
    raise FileNotFoundError(f'Missing launcher script: {launcher_path}')

spec = importlib.util.spec_from_file_location('forensicore_launcher', launcher_path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

module.run_video_pipeline()
